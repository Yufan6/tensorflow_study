# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
# Out:
# /home/yufan/PycharmProjects/tensorflow_study/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/yufan/PycharmProjects/tensorflow_study/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/yufan/PycharmProjects/tensorflow_study/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/yufan/PycharmProjects/tensorflow_study/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/yufan/PycharmProjects/tensorflow_study/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/yufan/PycharmProjects/tensorflow_study/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/yufan/PycharmProjects/tensorflow_study/venv/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/yufan/PycharmProjects/tensorflow_study/venv/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/yufan/PycharmProjects/tensorflow_study/venv/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/yufan/PycharmProjects/tensorflow_study/venv/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/yufan/PycharmProjects/tensorflow_study/venv/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/yufan/PycharmProjects/tensorflow_study/venv/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# 载入数据集
mnist = input_data.read_data_sets("MNIST_data",one_hot=True)

# 每个批次的大小
batch_size = 50
# 计算一共有多少批次
n_batch = mnist.train.num_examples // batch_size

# 定义两个placeholder
x = tf.placeholder(tf.float32,[None,784])
y = tf.placeholder(tf.float32,[None,10])

# 创建一个简单的神经网络
W1 = tf.Variable(tf.zeros([784,10]))
b1 = tf.Variable(tf.zeros([10]))
prediction = tf.nn.softmax(tf.matmul(x,W1)+b1)

# 对数释然函数
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=prediction,labels=y))
# 梯度下降法
#optimizer = tf.train.GradientDescentOptimizer(0.2)
optimizer = tf.train.GradientDescentOptimizer(0.2)
train = optimizer.minimize(loss)

# 初始化变量
init = tf.global_variables_initializer()

# 结果存放在一个布尔型列表中
correct_prediction = tf.equal(tf.argmax(y,1),tf.argmax(prediction,1)) #argmax返回一维tensor中最大值所在的位置
# 求准确率
accuarcy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(201):
        for batch in range(n_batch):
            batch_xs,batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train,feed_dict={x:batch_xs,y:batch_ys})
        acc = sess.run(accuarcy,feed_dict={x:mnist.test.images,y:mnist.test.labels})
        print("Iter " + str(epoch)+ ", Test accuarcy" + str(acc))
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Iter 0, Test accuarcy0.8881
# Iter 1, Test accuarcy0.9069
# Iter 2, Test accuarcy0.9098
# Iter 3, Test accuarcy0.9129
# Iter 4, Test accuarcy0.9165
# Iter 5, Test accuarcy0.9181
# Iter 6, Test accuarcy0.9198
# Iter 7, Test accuarcy0.9194
# Iter 8, Test accuarcy0.921
# Iter 9, Test accuarcy0.9205
# Iter 10, Test accuarcy0.9226
# Iter 11, Test accuarcy0.9227
# Iter 12, Test accuarcy0.9227
# Iter 13, Test accuarcy0.9225
# Iter 14, Test accuarcy0.9224
# Iter 15, Test accuarcy0.9235
# Iter 16, Test accuarcy0.9242
# Iter 17, Test accuarcy0.9247
# Iter 18, Test accuarcy0.9237
# Iter 19, Test accuarcy0.9261
# Iter 20, Test accuarcy0.9252
# Iter 21, Test accuarcy0.9269
# Iter 22, Test accuarcy0.9259
# Iter 23, Test accuarcy0.9266
# Iter 24, Test accuarcy0.9268
# Iter 25, Test accuarcy0.9278
# Iter 26, Test accuarcy0.9273
# Iter 27, Test accuarcy0.9264
# Iter 28, Test accuarcy0.9265
# Iter 29, Test accuarcy0.9276
# Iter 30, Test accuarcy0.9275
# Iter 31, Test accuarcy0.9266
# Iter 32, Test accuarcy0.9273
# Iter 33, Test accuarcy0.927
# Iter 34, Test accuarcy0.9272
# Iter 35, Test accuarcy0.9283
# Iter 36, Test accuarcy0.9283
# Iter 37, Test accuarcy0.9275
# Iter 38, Test accuarcy0.9282
# Iter 39, Test accuarcy0.9279
# Iter 40, Test accuarcy0.9272
# Iter 41, Test accuarcy0.9283
# Iter 42, Test accuarcy0.9282
# Iter 43, Test accuarcy0.9284
# Iter 44, Test accuarcy0.9284
# Iter 45, Test accuarcy0.9279
# Iter 46, Test accuarcy0.9282
# Iter 47, Test accuarcy0.9285
# Iter 48, Test accuarcy0.929
# Iter 49, Test accuarcy0.9292
# Iter 50, Test accuarcy0.929
# Iter 51, Test accuarcy0.9287
# Iter 52, Test accuarcy0.9283
# Iter 53, Test accuarcy0.9276
# Iter 54, Test accuarcy0.9287
# Iter 55, Test accuarcy0.9281
# Iter 56, Test accuarcy0.9283
# Iter 57, Test accuarcy0.9285
# Iter 58, Test accuarcy0.9281
# Iter 59, Test accuarcy0.9283
# Iter 60, Test accuarcy0.928
# Iter 61, Test accuarcy0.928
# Iter 62, Test accuarcy0.9293
# Iter 63, Test accuarcy0.9292
# Iter 64, Test accuarcy0.9287
# Iter 65, Test accuarcy0.9288
# Iter 66, Test accuarcy0.929
# Iter 67, Test accuarcy0.9285
# Iter 68, Test accuarcy0.929
# Iter 69, Test accuarcy0.9289
# Iter 70, Test accuarcy0.9289
# Iter 71, Test accuarcy0.9288
# Iter 72, Test accuarcy0.9286
# Iter 73, Test accuarcy0.9292
# Iter 74, Test accuarcy0.9293
# Iter 75, Test accuarcy0.9294
# Iter 76, Test accuarcy0.9284
# Iter 77, Test accuarcy0.9284
# Iter 78, Test accuarcy0.929
# Iter 79, Test accuarcy0.9292
# Iter 80, Test accuarcy0.9284
# Iter 81, Test accuarcy0.9283
# Iter 82, Test accuarcy0.9297
# Iter 83, Test accuarcy0.9292
# Iter 84, Test accuarcy0.9301
# Iter 85, Test accuarcy0.9294
# Iter 86, Test accuarcy0.9294
# Iter 87, Test accuarcy0.9286
# Iter 88, Test accuarcy0.9285
# Iter 89, Test accuarcy0.9295
# Iter 90, Test accuarcy0.9295
# Iter 91, Test accuarcy0.929
# Iter 92, Test accuarcy0.9296
# Iter 93, Test accuarcy0.9291
# Iter 94, Test accuarcy0.9291
# Iter 95, Test accuarcy0.9291
# Iter 96, Test accuarcy0.9294
# Iter 97, Test accuarcy0.9292
# Iter 98, Test accuarcy0.9295
# Iter 99, Test accuarcy0.9292
# Iter 100, Test accuarcy0.9292
# Iter 101, Test accuarcy0.93
# Iter 102, Test accuarcy0.9298
# Iter 103, Test accuarcy0.9298
# Iter 104, Test accuarcy0.9296
# Iter 105, Test accuarcy0.9285
# Iter 106, Test accuarcy0.9296
# Iter 107, Test accuarcy0.9294
# Iter 108, Test accuarcy0.9297
# Iter 109, Test accuarcy0.9301
# Iter 110, Test accuarcy0.9297
# Iter 111, Test accuarcy0.9299
# Iter 112, Test accuarcy0.9291
# Iter 113, Test accuarcy0.9295
# Iter 114, Test accuarcy0.9298
# Iter 115, Test accuarcy0.9302
# Iter 116, Test accuarcy0.9301
# Iter 117, Test accuarcy0.929
# Iter 118, Test accuarcy0.9303
# Iter 119, Test accuarcy0.9287
# Iter 120, Test accuarcy0.9295
# Iter 121, Test accuarcy0.9301
# Iter 122, Test accuarcy0.9287
# Iter 123, Test accuarcy0.9303
# Iter 124, Test accuarcy0.9297
# Iter 125, Test accuarcy0.9299
# Iter 126, Test accuarcy0.9292
# Iter 127, Test accuarcy0.9297
# Iter 128, Test accuarcy0.93
# Iter 129, Test accuarcy0.9297
# Iter 130, Test accuarcy0.93
# Iter 131, Test accuarcy0.9302
# Iter 132, Test accuarcy0.9296
# Iter 133, Test accuarcy0.9297
# Iter 134, Test accuarcy0.9301
# Iter 135, Test accuarcy0.93
# Iter 136, Test accuarcy0.9302
# Iter 137, Test accuarcy0.9301
# Iter 138, Test accuarcy0.9297
# Iter 139, Test accuarcy0.9299
# Iter 140, Test accuarcy0.93
# Iter 141, Test accuarcy0.9298
# Iter 142, Test accuarcy0.9299
# Iter 143, Test accuarcy0.929
# Iter 144, Test accuarcy0.9303
# Iter 145, Test accuarcy0.9307
# Iter 146, Test accuarcy0.93
# Iter 147, Test accuarcy0.9295
# Iter 148, Test accuarcy0.9302
# Iter 149, Test accuarcy0.9293
# Iter 150, Test accuarcy0.93
# Iter 151, Test accuarcy0.9298
# Iter 152, Test accuarcy0.93
# Iter 153, Test accuarcy0.929
# Iter 154, Test accuarcy0.9301
# Iter 155, Test accuarcy0.9299
# Iter 156, Test accuarcy0.93
# Iter 157, Test accuarcy0.9295
# Iter 158, Test accuarcy0.9302
# Iter 159, Test accuarcy0.9291
# Iter 160, Test accuarcy0.9302
# Iter 161, Test accuarcy0.9289
# Iter 162, Test accuarcy0.9303
# Iter 163, Test accuarcy0.9298
# Iter 164, Test accuarcy0.9302
# Iter 165, Test accuarcy0.9301
# Iter 166, Test accuarcy0.9298
# Iter 167, Test accuarcy0.9299
# Iter 168, Test accuarcy0.9295
# Iter 169, Test accuarcy0.9289
# Iter 170, Test accuarcy0.9297
# Iter 171, Test accuarcy0.9298
# Iter 172, Test accuarcy0.9298
# Iter 173, Test accuarcy0.93
# Iter 174, Test accuarcy0.93
# Iter 175, Test accuarcy0.93
# Iter 176, Test accuarcy0.9287
# Iter 177, Test accuarcy0.9299
# Iter 178, Test accuarcy0.9297
# Iter 179, Test accuarcy0.9293
# Iter 180, Test accuarcy0.9291
# Iter 181, Test accuarcy0.9296
# Iter 182, Test accuarcy0.9296
# Iter 183, Test accuarcy0.9295
# Iter 184, Test accuarcy0.9298
# Iter 185, Test accuarcy0.93
# Iter 186, Test accuarcy0.9302
# Iter 187, Test accuarcy0.93
# Iter 188, Test accuarcy0.9302
# Iter 189, Test accuarcy0.9298
# Iter 190, Test accuarcy0.9298
# Iter 191, Test accuarcy0.9299
# Iter 192, Test accuarcy0.9304
# Iter 193, Test accuarcy0.9301
# Iter 194, Test accuarcy0.93
# Iter 195, Test accuarcy0.93
# Iter 196, Test accuarcy0.93
# Iter 197, Test accuarcy0.9301
# Iter 198, Test accuarcy0.9299
# Iter 199, Test accuarcy0.9298
# Iter 200, Test accuarcy0.9297
